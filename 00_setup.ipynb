# %% [markdown]
# # SETUP

# %%
# !. .venv/bin/activate
# !uv add "langchain>=1.0,<2" langchain-ollama langchain-text-splitters
# mevcut yama: pip install langchain==1.3.15
# Out:
# Resolved 51 packages in 560ms
# ⠹ Preparing packages... (0/2)
# ⠹ Preparing packages... (0/2)-------------------     0 B/14.76 KiB
# ⠹ Preparing packages... (0/2)---------- 14.76 KiB/14.76 KiB
# ⠹ Preparing packages... (0/2)---------- 14.76 KiB/14.76 KiB
# ollama               ------------------------------ 14.76 KiB/14.76 KiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/30.68 KiB
# ollama               ------------------------------ 14.76 KiB/14.76 KiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/30.68 KiB
# ⠹ Preparing packages... (0/2)-------------------     0 B/30.68 KiB
# ⠹ Preparing packages... (0/2)--------------- 16.00 KiB/30.68 KiB
# ⠹ Preparing packages... (0/2)---------- 29.37 KiB/30.68 KiB
# ⠹ Preparing packages... (0/2)---------- 30.68 KiB/30.68 KiB
# Prepared 2 packages in 270ms
# Installed 2 packages in 3ms1.0
#  + langchain-ollama==1.1.0
#  + ollama==0.6.2

# %%
import langchain
langchain.__version__
# Out:
# '1.3.15'

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model_provider = 'ollama',
    model='qwen3.5:9b',
    validate_model_on_init=True,
    temperature=0.7,
)
model.invoke('Hello, how are you?')
# Out:
# AIMessage(content="Hello! I'm doing well, thank you for asking. How about you? Is there anything I can help you with today?", additional_kwargs={}, response_metadata={'model': 'qwen3.5:9b', 'created_at': '2026-08-16T12:48:08.569492762Z', 'done': True, 'done_reason': 'stop', 'total_duration': 55690838031, 'load_duration': 49976331864, 'prompt_eval_count': 16, 'prompt_eval_duration': 56421115, 'eval_count': 435, 'eval_duration': 5303313262, 'logprobs': None, 'model_name': 'qwen3.5:9b', 'model_provider': 'ollama'}, id='lc_run--01a00a9c-9879-7bb2-adba-ac175fc13faf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 435, 'total_tokens': 451})

# %%
print(model.invoke('ping').content)
# Out:
# Pong! 🟢 How can I assist you today?

# %%
# !uv pip show langchain langchain-core
# Out:
# Name: langchain
# Version: 1.3.15
# Location: /home/eplinux/langchain-study/.venv/lib/python3.13/site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# ---
# Name: langchain-core
# Version: 1.5.5
# Location: /home/eplinux/langchain-study/.venv/lib/python3.13/site-packages
# Requires: httpx, jsonpatch, langchain-protocol, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions, uuid-utils
# Required-by: langchain, langchain-ollama, langchain-openai, langchain-text-splitters, langgraph, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk
